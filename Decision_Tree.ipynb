# %% [markdown]
# <a href="https://colab.research.google.com/github/cutepuppy2024/Co_Lab_upload/blob/main/Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %%
model = DecisionTreeClassifier(max_depth=4)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
from sklearn import tree
plt.figure(figsize=(15, 15))
tree.plot_tree(model)
plt.show()
